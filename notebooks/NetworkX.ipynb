# %%
import networkx as nx
print(nx.__version__)
# Out:
# 3.6.1

# %% [markdown]
# ## 无向图

# %%
# 创建一个无向图
G = nx.Graph()

# 添加节点
G.add_node(1)
G.add_nodes_from(['A', 'B', 'C'])
# 添加边
G.add_edge(1, 'A')
G.add_edges_from([('A', 'B'), ('B', 'C')])

# 打印图的信息
print("Nodes:", G.nodes())
print("Edges:", G.edges())

# 可视化图
nx.draw(G, with_labels=True,pos=nx.spring_layout(G)) 
# pos 作用是指定节点布局方式，这里使用的是弹簧布局（spring layout），它会根据节点之间的连接关系自动调整节点的位置，使得图形看起来更美观。
# Out:
# Nodes: [1, 'A', 'B', 'C']
# Edges: [(1, 'A'), ('A', 'B'), ('B', 'C')]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 16
#      12 print("Nodes:", G.nodes())
#      13 print("Edges:", G.edges())
#      14
#      15 # 可视化图
# ---> 16 nx.draw(G, with_labels=True,pos=nx.spring_layout(G))
#      17 # pos 作用是指定节点布局方式，这里使用的是弹簧布局（spring layout），它会根据节点之间的连接关系自动调整节点的位置，使得图形看起来更美观。
#      18
#
# File d:\miniconda3\envs\gnn\Lib\site-packages\networkx\utils\decorators.py:784, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     783 def func(*args, __wrapper=None, **kwargs):
# --> 784     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 8:3, in argmap_spring_layout_5(G, k, pos, fixed, iterations, threshold, weight, scale, center, dim, seed, store_pos_as, method, gravity)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#       6 import re
#
# File d:\miniconda3\envs\gnn\Lib\site-packages\networkx\utils\misc.py:284, in create_random_state(random_state)
#     271 def create_random_state(random_state=None):
#     272     """Returns a numpy.random.RandomState or numpy.random.Generator instance
#     273     depending on input.
#     274
#    (...)    282         by numpy.random.
#     283     """
# --> 284     import numpy as np
#     286     if random_state is None or random_state is np.random:
#     287         return np.random.mtrand._rand
#
# ModuleNotFoundError: No module named 'numpy'

# %%
print(nx.is_directed(G))  # 检查图是否为有向图
print(nx.is_weighted(G))  # 检查图是否为加权图
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(nx.is_directed(G))  # 检查图是否为有向图
#       2 print(nx.is_weighted(G))  # 检查图是否为加权图
#
# NameError: name 'nx' is not defined
